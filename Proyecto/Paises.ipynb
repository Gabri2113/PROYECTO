# %%
import pandas as pd
import matplotlib.pyplot as plt
import copy
import tabulate
import openpyxl
import ast
import seaborn as sns

df = pd.read_csv(r"C:\Users\gabri\Documents\PYTHON\Archivos youtube\data_jobs.csv")
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x : ast.literal_eval(x) if pd.notna(x) else x)

# %% [markdown]
# CANTIDAD DE OFERTAS DE TRABAJO POR PAIS DE ANALISTA DE DATOS.

# %%
df.sample(5)
# Out:
#               job_title_short  \
# 181290           Data Analyst
# 701266          Data Engineer
# 626593  Senior Data Scientist
# 40733          Data Scientist
# 651489           Data Analyst
#
#                                                 job_title     job_location  \
# 181290       Health IT Business Intelligence/Data Analyst  Tallahassee, FL
# 701266  Azure Data Engineer- Bristol based- £550 outsi...      Bristol, UK
# 626593                              Senior Data Scientist     Meridian, MS
# 40733                           Praktikum Data Governance  Vienna, Austria
# 651489                                    Data Analyst II   Carrollton, TX
#
#                      job_via         job_schedule_type  job_work_from_home  \
# 181290   via Relocation Jobs                 Full-time               False
# 701266          via LinkedIn                 Full-time               False
# 626593       via Trabajo.org                 Full-time               False
# ...

# %%
df.shape
# Out:
# (785741, 17)

# %%
df_da = df.query('job_title_short == "Data Analyst"')

# %%
df_da.to_csv(r'C:\Users\gabri\Desktop\Dato.csv')

# %%
df_da.shape
# Out:
# (196075, 17)

# %%
df_da['job_country'].value_counts().head(10)
# Out:
# job_country
# United States     67816
# France            13803
# United Kingdom    10482
# Germany            7131
# Singapore          6632
# India              6121
# Spain              5177
# Philippines        4766
# Italy              4543
# Netherlands        4123
# Name: count, dtype: int64

# %%
df_plot_job_jolaction = df_da['job_country'].value_counts().head(10)

# %%
dft = df_plot_job_jolaction.reset_index(name='Count')

# %%
plt.figure(figsize=(15,5))
sns.set_theme(style='ticks')
sns.barplot(data=dft , x='job_country',y= 'Count',hue='job_country',palette='dark:b_r')
# plt.xticks( ha='right')
plt.tight_layout
plt.ylabel('')
plt.yticks([])
plt.title('Oferta de trabajo por pais para Analistas de Datos.',fontsize=25)
plt.show()

# %%
df_df = df_plot_job_jolaction.reset_index(name='cantidad')

# %%
df_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   job_country  10 non-null     object
#  1   cantidad     10 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 292.0+ bytes

# %%
df_df
# Out:
#       job_country  cantidad
# 0   United States     67816
# 1          France     13803
# 2  United Kingdom     10482
# 3         Germany      7131
# 4       Singapore      6632
# 5           India      6121
# 6           Spain      5177
# 7     Philippines      4766
# 8           Italy      4543
# 9     Netherlands      4123

# %%
df_df['Porcentaje_total'] = ((df_df['cantidad'] / total)*100)

# %%
df_df
# Out:
#       job_country  cantidad  Porcentaje_total
# 0   United States     67816         34.586765
# 1          France     13803          7.039653
# 2  United Kingdom     10482          5.345914
# 3         Germany      7131          3.636874
# 4       Singapore      6632          3.382379
# 5           India      6121          3.121765
# 6           Spain      5177          2.640316
# 7     Philippines      4766          2.430703
# 8           Italy      4543          2.316971
# 9     Netherlands      4123          2.102767

# %%
total =  df_da['job_title_short'].count()

# %%
total
# Out:
# np.int64(196075)

# %%
df_da
# Out:
#        job_title_short                                          job_title  \
# 1         Data Analyst                                       Data Analyst
# 12        Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18        Data Analyst                                       Data Analyst
# 31        Data Analyst                           Stage - Data Analyst F/H
# 34        Data Analyst  Data Analyst als Marketing Manager Automation ...
# ...                ...                                                ...
# 785703    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst          Expert Business Data Analyst - Now Hiring
# 785715    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 785717    Data Analyst                 Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                                   CRM Data Analyst
#
#                         job_location  \
# 1       Guadalajara, Jalisco, Mexico
# ...

# %%
df_da.shape
# Out:
# (196075, 18)
